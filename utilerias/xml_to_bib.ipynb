# %%
import re

# %%
archivoXML = open("Filepath", encoding="utf-8")

texto = archivoXML.read()

print(texto)
# Out:
# <?xml version="1.0"?>
# <b:Sources SelectedStyle="" xmlns:b="http://schemas.openxmlformats.org/officeDocument/2006/bibliography" xmlns="http://schemas.openxmlformats.org/officeDocument/2006/bibliography"><b:Source><b:Tag>Ben15</b:Tag><b:SourceType>JournalArticle</b:SourceType><b:Guid>{F8744CD3-9AE4-4013-AE9B-6DC8C3F2712C}</b:Guid><b:Title>Sistema Web para instituciones de nivel superior autenticador de alumnos mediante reconocimiento facial para la administración de trámites escolares</b:Title><b:Year>2015</b:Year><b:Pages>146</b:Pages><b:Author><b:Author><b:NameList><b:Person><b:Last>Benitez</b:Last><b:First>Daniela</b:First></b:Person><b:Person><b:Last>Ruiz</b:Last><b:First>Arturo</b:First></b:Person><b:Person><b:Last>Toscano</b:Last><b:First>Ricardo</b:First></b:Person></b:NameList></b:Author></b:Author></b:Source><b:Source><b:Tag>Gon19</b:Tag><b:SourceType>JournalArticle</b:SourceType><b:Guid>{24DF95F5-7D72-408D-BCA2-7298E4457170}</b:Guid><b:Author><b:Author><b:NameList><b:Person><b:Last>González</b:Last><b:First>Sergio</b:First></b:Person></b:NameList></b:Author></b:Author><b:Title>Algoritmo de extraccion de características faciales para la clasificación de individuos por edad</b:Title><b:JournalName>Universidad de Valladolid</b:JournalName><b:Year>2019</b:Year><b:Pages>152</b:Pages></b:Source><b:Source><b:Tag>Pyt23</b:Tag><b:SourceType>InternetSite</b:SourceType><b:Guid>{B21F0196-7524-47F6-B321-F6E6E1B3A624}</b:Guid><b:Author><b:Author><b:Corporate>Python inc</b:Corporate></b:Author></b:Author><b:Title>Python</b:Title><b:Year>2023</b:Year><b:InternetSiteTitle>Python.org</b:InternetSiteTitle><b:URL>https://www.python.org</b:URL></b:Source><b:Source><b:Tag>Miz</b:Tag><b:SourceType>InternetSite</b:SourceType><b:Guid>{145F2B1D-7C15-4AA6-8B27-E7D88E63AAEF}</b:Guid><b:Author><b:Author><b:Corporate>Mozilla Corporation</b:Corporate></b:Author></b:Author><b:Title>JavaScript</b:Title><b:InternetSiteTitle>mozilla.org</b:InternetSiteTitle><b:URL>https://developer.mozilla.org/es/docs/Web/JavaScript</b:URL></b:Source><b:Source><b:Tag>Gue08</b:Tag><b:SourceType>JournalArticle</b:SourceType><b:Guid>{7315F7FF-0B60-42FE-BF46-2564E7D362C9}</b:Guid><b:Title>DETECCIÓN DE ROSTROS EN IMÁGENES DIGITALES USANDO CLASIFICADORES EN </b:Title><b:Year>2008</b:Year><b:Author><b:Author><b:NameList><b:Person><b:Last>Guevara</b:Last><b:First>Martha</b:First></b:Person><b:Person><b:Last>Echeverry</b:Last><b:First>Julian</b:First></b:Person><b:Person><b:Last>Ardila</b:Last><b:First>William</b:First></b:Person></b:NameList></b:Author></b:Author><b:JournalName>Scientia et Technica</b:JournalName></b:Source><b:Source><b:Tag>Met13</b:Tag><b:SourceType>InternetSite</b:SourceType><b:Guid>{A1C61708-C8A8-4151-99FE-3603CA12D5B8}</b:Guid><b:Author><b:Author><b:Corporate>Meta</b:Corporate></b:Author></b:Author><b:Title>React</b:Title><b:Year>2023</b:Year><b:InternetSiteTitle>React</b:InternetSiteTitle><b:URL>https://es.react.dev</b:URL></b:Source><b:Source><b:Tag>BRO</b:Tag><b:SourceType>InternetSite</b:SourceType><b:Guid>{D3187E93-CDEC-4248-BBF0-4632DC74FD18}</b:Guid><b:Author><b:Author><b:Corporate>BROOBE</b:Corporate></b:Author></b:Author><b:Title>STELLACAST</b:Title><b:InternetSiteTitle>broobe</b:InternetSiteTitle><b:URL>https://www.broobe.com/es/portfolio/stellacast/</b:URL></b:Source><b:Source><b:Tag>Gue16</b:Tag><b:SourceType>JournalArticle</b:SourceType><b:Guid>{AF2AA193-D5FA-4290-A968-0747F77A97D0}</b:Guid><b:Title>Extracción de palabras clave usando hipergrafos</b:Title><b:Year>2016</b:Year><b:Author><b:Author><b:NameList><b:Person><b:Last>Guerrero</b:Last><b:First>Alejandra</b:First></b:Person><b:Person><b:Last>Silva</b:Last><b:First>Guillermo</b:First></b:Person></b:NameList></b:Author></b:Author><b:JournalName>Instituto Politecnico Nacional</b:JournalName></b:Source><b:Source><b:Tag>Tor20</b:Tag><b:SourceType>JournalArticle</b:SourceType><b:Guid>{877FB7F1-E381-461D-B1D2-5D6E74164823}</b:Guid><b:Author><b:Author><b:NameList><b:Person><b:Last>Torres</b:Last><b:First>Monica</b:Fir ...

# %%
filtro = re.compile(r"\>([\w\s]+)\<")

# %%
filtrado = ""

for etiqueta in re.findall(filtro, texto):

    # print(etiqueta)
    filtrado += etiqueta + "\n"
    # texto = texto.replace(etiqueta, "\n")

print(filtrado)
# Out:
# Ben15
# JournalArticle
# Sistema Web para instituciones de nivel superior autenticador de alumnos mediante reconocimiento facial para la administración de trámites escolares
# 2015
# 146
# Benitez
# Daniela
# Ruiz
# Arturo
# Toscano
# Ricardo
# Gon19
# JournalArticle
# González
# Sergio
# Algoritmo de extraccion de características faciales para la clasificación de individuos por edad
# Universidad de Valladolid
# 2019
# 152
# Pyt23
# InternetSite
# Python inc
# Python
# 2023
# Miz
# InternetSite
# Mozilla Corporation
# JavaScript
# Gue08
# JournalArticle
# DETECCIÓN DE ROSTROS EN IMÁGENES DIGITALES USANDO CLASIFICADORES EN
# 2008
# Guevara
# Martha
# Echeverry
# Julian
# Ardila
# William
# Scientia et Technica
# Met13
# InternetSite
# Meta
# React
# 2023
# React
# BRO
# InternetSite
# BROOBE
# STELLACAST
# broobe
# Gue16
# JournalArticle
# Extracción de palabras clave usando hipergrafos
# 2016
# Guerrero
# Alejandra
# Silva
# Guillermo
# Instituto Politecnico Nacional
# Tor20
# JournalArticle
# Torres
# Monica
# Roberto
# ASISTENTE VIRTUAL ACADÉMICO UTILIZANDO TECNOLOGÍAS COGNITIVAS DE PROCESAMIENTO DE LENGUAJE NATURAL
# Revista Politécnica
# 2020
# Redalyc
# 16
# Ang
# InternetSite
# Introduction to the Angular docs
# Angular
# Angular
# Gon21
# InternetSite
# Gonçalves
# Manuel
# Hiberus Blog
# 2021
# Octubre
# 13
# Mar
# InternetSite
# Marketing directo
# Agencia de modelos
# Pér23
# DocumentFromInternetSite
# Definición de Modelo
# ConceptoDefinicion
# 2023
# Julio
# 27
# Pérez
# Marina
# Cib
# InternetSite
# Cibermodelos
# Cibermodelos
# Cibermodelos
# 3
# Mol05
# JournalArticle
# 2005
# Enero
# Ciencia y tecnología para la salud visual y ocular
# Molina
# Nancy
# Mai15
# JournalArticle
# Maida
# Esteban
# Pacienzia
# Julián
# Metodologías de desarrollo de software
# Biblioteca digital de la Universidad Católica Argentina
# 2015
# Are22
# InternetSite
# Principios de usabilidad web de Jacob Nielsen y el diseño UX
# 2022
# Arenzana
# David
# Semrush Blog
# marzo
# 25
# 2023
# octubre
# 13
# Arc18
# DocumentFromInternetSite
# Arciniega
# Fernando
# Normas y Estándares de calidad para el desarrollo de Software
# 2018
# 2023
# octubre
# 13
# Cas
# InternetSite
# Productora
# Casting
# And23
# InternetSite
# Revisando los principios y prácticas generales del método Kanban
# 2023
# Octubre
# 22
# Anderson
# David
# 10
# 2010

# %%
with open("output.bib", mode="x") as output:
    output.write(filtrado)
