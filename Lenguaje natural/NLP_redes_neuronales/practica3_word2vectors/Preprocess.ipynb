# %% [markdown]
# # Preprocessing

# %%
import pandas as pd

# %%
dataset = pd.read_csv("./arceus_reviews.csv")
print(dataset)
# Out:
#                                                  review          date  score
# 0     A fun reinvention of the Pokémon formula, hope...  Jan 29, 2022     10  \
# 1     A fun, challenging (at times), Pokemon game wi...  Jan 30, 2022     10
# 2     El juego más infravalorado de la saga y posibl...  Jan 29, 2022     10
# 3     Best pokemon game of all time! New pokemon, ne...  Jan 30, 2022     10
# 4     One outstanding experience, that is certain. I...   Feb 3, 2022     10
# ...                                                 ...           ...    ...
# 1062  Final boss is too cheap, that is not fail at a...  Feb 13, 2022      0
# 1063  Boss fights aren’t thought out properly. Too m...  Feb 14, 2022      0
# 1064  not open world and kinda boring. graphics are ...  Feb 20, 2022      0
# 1065  Schwaches Spiel... (Meiner Meinung nach)Grafik...  Feb 25, 2022      0
# 1066  poikemon es un juego rpg, no es un juego de co...  Feb 28, 2022      0
#
# ...

# %%
from text_preprocessing.scripts.text_preprocessing import Preprocessing
# Out:
# ...
# 2024-01-06 22:07:14.850604: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-06 22:07:14.850683: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-06 22:07:14.852298: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-06 22:07:16.417519: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-01-06 22:07:21.040662: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %%
prep_en = Preprocessing("english")

# %%
preprocessed_df = prep_en.main_preprocess(data = dataset,  column= 'review',  tweet = True, tweet_tags = True, remove_stop_words = True,  lemmatize = True, translate_emojis = True, whitelist= 'ñ')

print(preprocessed_df)
# Out:
#                                                  review          date  score
# 0     fun reinvention pokemon formula hopefully next...  Jan 29, 2022     10  \
# 1     fun challenge time pokemon game addictive game...  Jan 30, 2022     10
# 2     el juego mas infravalorado de la saga posiblem...  Jan 29, 2022     10
# 3     good pokemon game time new pokemon new stuff n...  Jan 30, 2022     10
# 4     one outstanding experience certain absolutely ...   Feb 3, 2022     10
# ...                                                 ...           ...    ...
# 1062        final boss cheap fail beyond type insulting  Feb 13, 2022      0
# 1063  boss fight think properly many bug sloppy deve...  Feb 14, 2022      0
# 1064  open world kinda boring graphic pretty bad beg...  Feb 20, 2022      0
# 1065  schwaches spiel meiner meinung nach grafikgame...  Feb 25, 2022      0
# 1066  poikemon es un juego rpg es un juego de combat...  Feb 28, 2022      0
#
# ...

# %%
# from sklearn.model_selection import train_test_split

# %%
# corpus = dataset["review"].values.tolist()
# target = dataset["score"].values.tolist()

# %%
from manejo_dataset_heartAttack import manejo_datasets

# %%
manejo_datasets(target_label="score", dataframe=preprocessed_df)
# Out:
#  Dataset
#                                                   review          date  score
# 0     fun reinvention pokemon formula hopefully next...  Jan 29, 2022     10  \
# 1     fun challenge time pokemon game addictive game...  Jan 30, 2022     10
# 2     el juego mas infravalorado de la saga posiblem...  Jan 29, 2022     10
# 3     good pokemon game time new pokemon new stuff n...  Jan 30, 2022     10
# 4     one outstanding experience certain absolutely ...   Feb 3, 2022     10
# ...                                                 ...           ...    ...
# 1062        final boss cheap fail beyond type insulting  Feb 13, 2022      0
# 1063  boss fight think properly many bug sloppy deve...  Feb 14, 2022      0
# 1064  open world kinda boring graphic pretty bad beg...  Feb 20, 2022      0
# 1065  schwaches spiel meiner meinung nach grafikgame...  Feb 25, 2022      0
# 1066  poikemon es un juego rpg es un juego de combat...  Feb 28, 2022      0
#
# ...
